# %%
# %load_ext tensorboard
# %tensorboard --logdir /yunity/tkerby2/Local_CorEx/Local_CorEx_Experiments/experiments/paper_neural_networks/mnist_classifier/model_output/base_classifier
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-dac3a012e503f4e8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-dac3a012e503f4e8");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
